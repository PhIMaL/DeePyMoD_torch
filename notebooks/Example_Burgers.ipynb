# %% [markdown]
# # Example Burgers' equation

# %% [markdown]
# In this notebook we provide a simple example of the DeepMoD algorithm by applying it on the Burgers' equation.
#
# We start by importing the required libraries and setting the plotting style:

# %%
import numpy as np
import torch
from deepymod_torch.library_function import library_1D_in
from deepymod_torch.DeepMod import DeepMoD

import matplotlib.pyplot as plt
plt.style.use('seaborn-notebook')

np.random.seed(40)

#torch.set_default_tensor_type('torch.cuda.FloatTensor')  # enable for gpu.

# %% [markdown]
# Next, we prepare the dataset.

# %%
data = np.load('../data/processed/burgers.npy', allow_pickle=True).item()
print('Shape of grid:', data['x'].shape)
# Out:
# Shape of grid: (256, 101)

# %% [markdown]
# Let's plot it to get an idea of the data:

# %%
fig, ax = plt.subplots()
im = ax.contourf(data['x'], data['t'], np.real(data['u']))
ax.set_xlabel('x')
ax.set_ylabel('t')
fig.colorbar(mappable=im)

plt.show()

# %%
X = np.transpose((data['t'].flatten(), data['x'].flatten()))
y = np.real(data['u']).reshape((data['u'].size, 1))

print(X.shape, y.shape)
# Out:
# (25856, 2) (25856, 1)

# %%
X
# Out:
# array([[ 0.    , -8.    ],
#        [ 0.1   , -8.    ],
#        [ 0.2   , -8.    ],
#        ...,
#        [ 9.8   ,  7.9375],
#        [ 9.9   ,  7.9375],
#        [10.    ,  7.9375]])

# %% [markdown]
# As we can see, $X$ has 2 dimensions, $\{x, t\}$, while $y$ has only one, $\{u\}$. Always explicity set the shape (i.e. $N\times 1$, not $N$) or you'll get errors. This dataset is noiseless, so let's add $5\%$ noise:

# %%
noise_level = 0.05
y_noisy = y + noise_level * np.std(y) * np.random.randn(y.size, 1)

# %% [markdown]
# The dataset is also much larger than needed, so let's hussle it and pick out a 1000 samples:

# %%
number_of_samples = 1000

idx = np.random.permutation(y.size)
X_train = torch.tensor(X[idx, :][:number_of_samples], dtype=torch.float32, requires_grad=True)
y_train = torch.tensor(y_noisy[idx, :][:number_of_samples], dtype=torch.float32)

# %%
print(X_train.shape, y_train.shape)
# Out:
# torch.Size([1000, 2]) torch.Size([1000, 1])

# %% [markdown]
# We now have a dataset which we can use. Let's plot, for a final time, the original dataset, the noisy set and the samples points:

# %%
fig, axes = plt.subplots(ncols=3, figsize=(15, 4))

im0 = axes[0].contourf(data['x'], data['t'], np.real(data['u']), cmap='coolwarm')
axes[0].set_xlabel('x')
axes[0].set_ylabel('t')
axes[0].set_title('Ground truth')

im1 = axes[1].contourf(data['x'], data['t'], y_noisy.reshape(data['x'].shape), cmap='coolwarm')
axes[1].set_xlabel('x')
axes[1].set_title('Noisy')

sampled = np.array([y_noisy[index, 0] if index in idx[:number_of_samples] else np.nan for index in np.arange(data['x'].size)])
sampled = np.rot90(sampled.reshape(data['x'].shape)) #array needs to be rotated because of imshow

im2 = axes[2].imshow(sampled, aspect='auto', cmap='coolwarm')
axes[2].set_xlabel('x')
axes[2].set_title('Sampled')

fig.colorbar(im1, ax=axes.ravel().tolist())

plt.show()

# %% [markdown]
# ## Configure the neural network

# %% [markdown]
# We now setup the options for DeepMoD. There's as few dictionaries to fill, starting with the 'optim config', which sets the maximal number of iterations and the amplitude of the $L_1$ penalty

# %%
optim_config = {'lambda': 10**-5, 'max_iterations': 20000}

# %% [markdown]
# Next we choose the size of the neural network

# %%
network_config = {'input_dim': 2, 'hidden_dim': 20, 'layers': 5, 'output_dim': 1}

# %% [markdown]
# DeepMoD accepts any arbitrary library function and any options for it can be given through *the library_config*. The library function for the burgers case accepts a maximum order for the polynomial and derivative terms.

# %%
lib_config = {'type': library_1D_in, 'poly_order': 2, 'diff_order': 3}

# %% [markdown]
# ## Run DeepMoD

# %% [markdown]
# We can now run DeepMoD using all the options we have set and the training data. We also need to specify which library function we wish to use. You can build any library you want and just pass is through this command:

# %%
sparse_coeff_vector, sparsity_mask, network = DeepMoD(X_train, y_train, network_config, lib_config, optim_config)
# Out:
# Epoch | Total loss | MSE | PI | L1
# 0 5.1E-01 4.6E-02 4.6E-01 2.3E-03
# tensor([[-0.6836],
#         [ 0.2441],
#         [-1.0590],
#         [ 1.6611],
#         [ 0.1850],
#         [-0.7019],
#         [ 0.4375],
#         [ 1.6637],
#         [-0.0451],
#         [ 0.6706],
#         [-0.1395],
#         [-1.6934]], requires_grad=True)
# 500 2.2E-02 1.4E-02 7.9E-03 1.1E-04
# tensor([[-0.1976],
#         [ 0.7616],
#         [-0.2542],
#         [ 1.5396],
#         [ 0.6154],
#         [-0.4006],
#         [ 0.3261],
#         [ 1.5048],
#         [ 0.3577],
#         [ 1.0663],
#         [-0.4060],
#         [-1.8981]], requires_grad=True)
# 1000 6.7E-03 3.9E-03 2.6E-03 1.6E-04
# tensor([[-0.0835],
#         [ 0.4111],
#         [ 0.6960],
#         [ 0.6732],
#         [ 0.5493],
#         [-0.6961],
#         [ 1.2284],
#         [ 1.0464],
#         [ 0.2509],
#         [ 1.0777],
#         [ 0.3777],
#         [-2.7498]], requires_grad=True)
# 1500 3.6E-03 1.9E-03 1.6E-03 9.8E-05
# tensor([[-0.0462],
#         [ 0.0971],
#         [ 0.3274],
#         [ 0.1028],
#         [ 0.4244],
#         [-1.3105],
#         [ 1.1725],
#         [ 1.1466],
#         [ 0.1403],
#         [ 0.2518],
#         [ 0.2611],
#         [-2.9867]], requires_grad=True)
# 2000 1.7E-03 1.2E-03 4.0E-04 7.8E-05
# tensor([[-1.8484e-02],
#         [-4.9587e-02],
#         [ 4.3971e-02],
#         [-7.5622e-02],
#         [ 2.9072e-01],
#         [-2.0497e+00],
#         [ 1.2226e+00],
#         [ 1.9819e-01],
#         [-2.7124e-04],
#         [-6.7962e-01],
#         [ 1.0438e-01],
#         [-1.3692e+00]], requires_grad=True)
# 2500 5.5E-04 3.2E-04 1.5E-04 7.8E-05
# tensor([[-0.0075],
#         [-0.0088],
#         [-0.0150],
#         [-0.0365],
#         [ 0.2141],
#         [-2.0969],
#         [ 1.1485],
#         [ 0.0657],
#         [-0.0680],
#         [-0.4016],
#         [-0.2894],
#         [-0.8153]], requires_grad=True)
# 3000 3.2E-04 1.8E-04 6.7E-05 7.2E-05
# tensor([[-0.0042],
#         [ 0.0207],
#         [ 0.0026],
#         [-0.0170],
#         [ 0.1566],
#         [-1.9108],
#         [ 0.9961],
#         [ 0.0411],
#         [-0.1067],
#         [ 0.0281],
#         [-0.6301],
#         [-0.4788]], requires_grad=True)
# 3500 2.3E-04 1.3E-04 3.3E-05 6.4E-05
# tensor([[-0.0017],
#         [ 0.0127],
#         [ 0.0079],
#         [-0.0094],
#         [ 0.1174],
#         [-1.7087],
#         [ 0.8591],
#         [ 0.0146],
#         [-0.1248],
#         [ 0.2440],
#         [-0.7161],
#         [-0.2654]], requires_grad=True)
# 4000 1.9E-04 1.1E-04 2.3E-05 5.5E-05
# tensor([[-4.7823e-04],
#         [-8.6400e-06],
#         [ 1.1794e-02],
#         [-5.7139e-03],
#         [ 9.5278e-02],
#         [-1.5539e+00],
#         [ 7.2357e-01],
#         [ 3.9211e-05],
#         [-1.2285e-01],
#         [ 3.6273e-01],
#         [-6.5619e-01],
#         [-1.3687e-01]], requires_grad=True)
# 4500 4.9E-04 4.1E-04 3.2E-05 5.0E-05
# tensor([[-1.1595e-04],
#         [-1.1608e-03],
#         [ 2.2045e-02],
#         [-3.9343e-03],
#         [ 7.7913e-02],
#         [-1.4459e+00],
#         [ 5.7067e-01],
#         [-6.1506e-04],
#         [-1.1263e-01],
#         [ 4.2091e-01],
#         [-5.3391e-01],
#         [-7.4888e-02]], requires_grad=True)
# 5000 1.4E-04 8.7E-05 1.2E-05 4.0E-05
# tensor([[ 6.8457e-07],
#         [-3.6631e-03],
#         [ 3.8922e-02],
#         [-3.0871e-03],
#         [ 6.0962e-02],
#         [-1.3428e+00],
#         [ 4.0905e-01],
#         [ 2.8657e-05],
#         [-9.9380e-02],
#         [ 4.3375e-01],
#         [-4.0279e-01],
#         [-3.2518e-02]], requires_grad=True)
# 5500 1.2E-04 8.3E-05 8.6E-06 3.3E-05
# tensor([[-9.0940e-07],
#         [-5.5522e-03],
#         [ 5.8044e-02],
#         [-1.6781e-03],
#         [ 4.5063e-02],
#         [-1.2482e+00],
#         [ 2.6122e-01],
#         [-4.5029e-05],
#         [-8.5159e-02],
#         [ 4.0829e-01],
#         [-2.7329e-01],
#         [-1.2851e-02]], requires_grad=True)
# 6000 1.1E-04 8.0E-05 7.5E-06 2.7E-05
# tensor([[-3.5338e-07],
#         [-6.0765e-03],
#         [ 7.6158e-02],
#         [-2.7715e-05],
#         [ 3.0875e-02],
#         [-1.1634e+00],
#         [ 1.3547e-01],
#         [ 1.0477e-05],
#         [-6.9292e-02],
#         [ 3.4284e-01],
#         [-1.5644e-01],
#         [-5.5317e-03]], requires_grad=True)
# 6500 1.1E-04 7.8E-05 7.1E-06 2.2E-05
# tensor([[-9.8471e-07],
#         [-6.8820e-03],
#         [ 8.9038e-02],
#         [ 7.0355e-04],
#         [ 1.9135e-02],
#         [-1.0957e+00],
#         [ 4.9972e-02],
#         [ 1.1611e-05],
#         [-5.1117e-02],
#         [ 2.5867e-01],
#         [-7.1343e-02],
#         [-2.1375e-03]], requires_grad=True)
# 7000 1.0E-04 7.7E-05 6.4E-06 1.8E-05
# tensor([[ 2.8075e-06],
#         [-7.2803e-03],
#         [ 9.7136e-02],
#         [ 1.8101e-03],
#         [ 8.7523e-03],
#         [-1.0364e+00],
#         [ 1.3589e-04],
#         [-2.6864e-05],
#         [-3.1054e-02],
#         [ 1.6087e-01],
#         [-1.6613e-02],
#         [-3.4703e-03]], requires_grad=True)
# 7500 9.8E-05 7.7E-05 5.3E-06 1.6E-05
# tensor([[ 7.0111e-05],
#         [-9.7974e-03],
#         [ 9.7597e-02],
#         [ 1.8542e-03],
#         [ 3.6692e-04],
#         [-9.8941e-01],
#         [-4.3295e-05],
#         [-1.5453e-05],
#         [-7.9267e-03],
#         [ 5.4461e-02],
#         [-3.5239e-03],
#         [-5.7182e-03]], requires_grad=True)
# 8000 9.5E-05 7.6E-05 4.3E-06 1.5E-05
# tensor([[ 4.7070e-06],
#         [-1.4333e-02],
#         [ 9.7336e-02],
#         [ 1.4981e-03],
#         [-1.4519e-06],
#         [-9.5404e-01],
#         [ 5.6878e-05],
#         [-6.0121e-06],
#         [-4.5131e-03],
#         [-8.5465e-05],
#         [-1.4539e-04],
#         [-4.8250e-03]], requires_grad=True)
# 8500 1.0E-04 8.2E-05 3.9E-06 1.5E-05
# tensor([[ 1.1069e-04],
#         [-1.6273e-02],
#         [ 9.6130e-02],
#         [ 8.4822e-04],
#         [-2.2806e-05],
#         [-9.4983e-01],
#         [ 1.8668e-04],
#         [ 5.1667e-05],
#         [-5.7211e-03],
#         [ 1.3703e-04],
#         [-6.4786e-05],
#         [-1.6859e-03]], requires_grad=True)
# 9000 9.3E-05 7.6E-05 3.1E-06 1.5E-05
# tensor([[ 3.0162e-05],
#         [-1.4593e-02],
#         [ 9.5803e-02],
#         [ 5.1464e-04],
#         [-3.7405e-06],
#         [-9.5333e-01],
#         [ 9.1416e-05],
#         [-8.3540e-07],
#         [-5.0855e-03],
#         [-2.6978e-04],
#         [-1.0875e-04],
#         [ 5.1053e-06]], requires_grad=True)
# 9500 9.3E-05 7.5E-05 2.6E-06 1.5E-05
# tensor([[ 1.6432e-05],
#         [-1.2351e-02],
#         [ 9.6170e-02],
#         [ 3.9166e-04],
#         [-6.3330e-07],
#         [-9.5960e-01],
#         [ 1.7061e-05],
#         [ 9.1258e-05],
#         [-4.6063e-03],
#         [-1.5472e-03],
#         [ 1.6086e-05],
#         [-1.2202e-05]], requires_grad=True)
# 10000 9.2E-05 7.5E-05 2.3E-06 1.5E-05
# tensor([[ 1.5544e-05],
#         [-1.0634e-02],
#         [ 9.6434e-02],
#         [ 2.8442e-04],
#         [-5.2577e-05],
#         [-9.6482e-01],
#         [ 2.4199e-05],
#         [ 7.3105e-05],
#         [-4.3988e-03],
#         [-1.4554e-03],
#         [ 1.1958e-05],
#         [ 5.5556e-05]], requires_grad=True)
# 10500 9.2E-05 7.5E-05 2.1E-06 1.5E-05
# tensor([[ 4.5583e-05],
#         [-9.3972e-03],
#         [ 9.6696e-02],
#         [ 1.8867e-04],
#         [-3.1869e-05],
#         [-9.6835e-01],
#         [ 2.2913e-04],
#         [ 2.0867e-04],
#         [-4.1514e-03],
#         [-1.6383e-03],
#         [-9.8773e-06],
#         [ 5.0898e-06]], requires_grad=True)
# 11000 1.2E-04 1.0E-04 3.2E-06 1.4E-05
# tensor([[-2.4451e-05],
#         [-8.8835e-03],
#         [ 9.5219e-02],
#         [ 4.5232e-05],
#         [-7.8536e-05],
#         [-9.6974e-01],
#         [ 4.7846e-04],
#         [ 4.2764e-04],
#         [-4.7288e-03],
#         [ 2.2531e-04],
#         [ 2.2433e-04],
#         [ 3.2979e-04]], requires_grad=True)
# 11500 9.1E-05 7.5E-05 1.8E-06 1.5E-05
# tensor([[-2.3673e-05],
#         [-8.4207e-03],
#         [ 9.6668e-02],
#         [ 3.4632e-05],
#         [-1.8702e-05],
#         [-9.7096e-01],
#         [ 8.8132e-05],
#         [ 2.8518e-04],
#         [-4.0621e-03],
#         [-2.0245e-03],
#         [ 1.4232e-04],
#         [ 5.1765e-04]], requires_grad=True)
# 12000 9.1E-05 7.5E-05 1.7E-06 1.5E-05
# tensor([[ 1.9042e-05],
#         [-7.7603e-03],
#         [ 9.6760e-02],
#         [ 2.0320e-05],
#         [-2.5006e-05],
#         [-9.7228e-01],
#         [ 3.4245e-04],
#         [ 1.5372e-04],
#         [-3.8800e-03],
#         [-2.8246e-03],
#         [ 9.6894e-05],
#         [ 8.0552e-04]], requires_grad=True)
# 12500 9.1E-05 7.5E-05 1.6E-06 1.5E-05
# tensor([[ 1.1784e-05],
#         [-7.1111e-03],
#         [ 9.6946e-02],
#         [ 8.3534e-05],
#         [-6.4382e-05],
#         [-9.7390e-01],
#         [ 5.8895e-06],
#         [ 1.1787e-04],
#         [-3.5943e-03],
#         [-2.7854e-03],
#         [ 1.8555e-04],
#         [ 9.1652e-04]], requires_grad=True)
# 13000 9.1E-05 7.5E-05 1.6E-06 1.5E-05
# tensor([[-2.2073e-05],
#         [-6.8721e-03],
#         [ 9.6826e-02],
#         [-7.0843e-06],
#         [ 2.3585e-05],
#         [-9.7457e-01],
#         [ 1.1586e-04],
#         [ 9.4982e-05],
#         [-3.5977e-03],
#         [-2.2540e-03],
#         [ 1.4519e-04],
#         [ 1.0219e-03]], requires_grad=True)
# 13500 9.1E-05 7.5E-05 1.5E-06 1.5E-05
# tensor([[ 1.7223e-05],
#         [-6.5965e-03],
#         [ 9.6846e-02],
#         [ 3.4718e-05],
#         [-1.2007e-04],
#         [-9.7520e-01],
#         [ 1.1764e-04],
#         [ 1.3544e-04],
#         [-3.3121e-03],
#         [-1.9919e-03],
#         [ 3.0227e-04],
#         [ 1.2474e-03]], requires_grad=True)
# 14000 9.0E-05 7.4E-05 1.4E-06 1.5E-05
# tensor([[ 6.1773e-05],
#         [-6.4211e-03],
#         [ 9.6877e-02],
#         [ 1.4509e-05],
#         [-2.1241e-04],
#         [-9.7560e-01],
#         [-8.5203e-05],
#         [ 1.0859e-04],
#         [-2.9373e-03],
#         [-1.7240e-03],
#         [ 1.0743e-04],
#         [ 1.2831e-03]], requires_grad=True)
# 14500 9.1E-05 7.5E-05 1.4E-06 1.5E-05
# tensor([[-3.4434e-06],
#         [-6.3044e-03],
#         [ 9.6667e-02],
#         [ 2.7953e-05],
#         [-1.1515e-04],
#         [-9.7577e-01],
#         [ 1.7910e-04],
#         [ 1.0602e-04],
#         [-3.5216e-03],
#         [-1.2731e-03],
#         [ 6.3793e-05],
#         [ 1.3837e-03]], requires_grad=True)
# 15000 9.0E-05 7.4E-05 1.4E-06 1.5E-05
# tensor([[-2.9708e-05],
#         [-6.0253e-03],
#         [ 9.6795e-02],
#         [ 5.2956e-05],
#         [-2.2970e-04],
#         [-9.7683e-01],
#         [ 2.4145e-05],
#         [ 5.1910e-05],
#         [-2.7994e-03],
#         [-1.1817e-03],
#         [ 2.1452e-04],
#         [ 1.3203e-03]], requires_grad=True)
# 15500 9.1E-05 7.5E-05 1.4E-06 1.5E-05
# tensor([[-7.1294e-05],
#         [-6.1377e-03],
#         [ 9.6517e-02],
#         [ 4.7321e-05],
#         [-2.3139e-04],
#         [-9.7612e-01],
#         [ 2.8514e-04],
#         [ 7.4449e-05],
#         [-2.8955e-03],
#         [-1.9631e-03],
#         [ 1.8998e-04],
#         [ 1.2484e-03]], requires_grad=True)
# 16000 9.0E-05 7.4E-05 1.3E-06 1.5E-05
# tensor([[ 3.8379e-05],
#         [-5.4854e-03],
#         [ 9.7052e-02],
#         [-7.8270e-06],
#         [-4.8451e-04],
#         [-9.7740e-01],
#         [ 8.0550e-05],
#         [ 7.7368e-05],
#         [-2.5758e-03],
#         [-1.9928e-03],
#         [ 3.7444e-04],
#         [ 1.2723e-03]], requires_grad=True)
# 16500 9.0E-05 7.4E-05 1.3E-06 1.5E-05
# tensor([[ 2.5919e-05],
#         [-5.1977e-03],
#         [ 9.7246e-02],
#         [ 5.2604e-05],
#         [-1.2197e-04],
#         [-9.7825e-01],
#         [ 6.1921e-05],
#         [ 1.0753e-04],
#         [-2.6086e-03],
#         [-1.8846e-03],
#         [ 9.0801e-05],
#         [ 1.1911e-03]], requires_grad=True)
# 17000 9.0E-05 7.5E-05 1.3E-06 1.5E-05
# tensor([[ 4.2591e-05],
#         [-5.3679e-03],
#         [ 9.7430e-02],
#         [ 3.8625e-05],
#         [-2.2096e-04],
#         [-9.7851e-01],
#         [ 1.3438e-04],
#         [ 5.2651e-05],
#         [-2.4212e-03],
#         [-7.1032e-04],
#         [ 2.5797e-04],
#         [ 1.3279e-03]], requires_grad=True)
# 17500 9.1E-05 7.5E-05 1.4E-06 1.5E-05
# tensor([[ 1.8889e-04],
#         [-4.9239e-03],
#         [ 9.6710e-02],
#         [ 7.2894e-05],
#         [ 9.5753e-05],
#         [-9.7907e-01],
#         [ 1.5212e-04],
#         [ 1.4334e-04],
#         [-3.4503e-03],
#         [-2.1608e-04],
#         [ 3.9423e-04],
#         [ 8.8776e-04]], requires_grad=True)
# 18000 9.8E-05 8.2E-05 1.9E-06 1.5E-05
# tensor([[ 4.6510e-05],
#         [-5.1039e-03],
#         [ 9.6900e-02],
#         [ 2.0054e-04],
#         [-6.3697e-06],
#         [-9.7941e-01],
#         [-8.1275e-05],
#         [ 2.5071e-04],
#         [-3.5234e-03],
#         [-5.4350e-04],
#         [ 1.4040e-04],
#         [ 7.5787e-04]], requires_grad=True)
# 18500 9.0E-05 7.4E-05 1.3E-06 1.5E-05
# tensor([[ 8.9651e-05],
#         [-4.4939e-03],
#         [ 9.7467e-02],
#         [ 3.9326e-05],
#         [-8.9446e-05],
#         [-9.8039e-01],
#         [ 1.8153e-04],
#         [ 1.8662e-04],
#         [-2.2179e-03],
#         [-1.5731e-03],
#         [ 1.9069e-04],
#         [ 8.4430e-04]], requires_grad=True)
# 19000 9.0E-05 7.4E-05 1.3E-06 1.5E-05
# tensor([[ 4.2422e-05],
#         [-4.7982e-03],
#         [ 9.7256e-02],
#         [ 3.3804e-05],
#         [-2.4490e-05],
#         [-9.8008e-01],
#         [ 3.3383e-04],
#         [ 2.0860e-04],
#         [-2.2191e-03],
#         [-7.7689e-04],
#         [ 1.3314e-04],
#         [ 7.3374e-04]], requires_grad=True)
# 19500 9.0E-05 7.4E-05 1.3E-06 1.5E-05
# tensor([[-6.2405e-05],
#         [-4.3485e-03],
#         [ 9.7785e-02],
#         [ 3.3308e-05],
#         [-8.7264e-06],
#         [-9.8147e-01],
#         [ 1.1902e-04],
#         [ 1.7938e-04],
#         [-1.7373e-03],
#         [-1.5016e-03],
#         [ 2.7804e-04],
#         [ 6.3585e-04]], requires_grad=True)
# [tensor([[-7.2637e-05],
#         [-4.3764e-03],
#         [ 9.7624e-02],
#         [ 1.1330e-04],
#         [-2.4394e-04],
#         [-9.8180e-01],
#         [ 3.8570e-05],
#         [ 7.8436e-05],
#         [-1.8393e-03],
#         [-2.0742e-03],
#         [ 4.7429e-04],
#         [ 3.1368e-04]], requires_grad=True)] (tensor([[ 0.0976],
#         [-0.9818]], requires_grad=True),) (tensor([2, 5]),)
# Now running final cycle.
# Epoch | Total loss | MSE | PI | L1
# 0 7.6E-05 7.4E-05 2.5E-06 0.0E+00
# tensor([[ 0.0996],
#         [-0.9838]], requires_grad=True)
# 500 7.5E-05 7.4E-05 1.3E-06 0.0E+00
# tensor([[ 0.0995],
#         [-0.9973]], requires_grad=True)
# 1000 7.5E-05 7.4E-05 1.3E-06 0.0E+00
# tensor([[ 0.0995],
#         [-0.9974]], requires_grad=True)
# 1500 7.5E-05 7.3E-05 1.3E-06 0.0E+00
# tensor([[ 0.0996],
#         [-0.9976]], requires_grad=True)
# 2000 7.5E-05 7.3E-05 1.3E-06 0.0E+00
# tensor([[ 0.0995],
#         [-0.9980]], requires_grad=True)
# 2500 7.7E-05 7.6E-05 1.4E-06 0.0E+00
# tensor([[ 0.0995],
#         [-0.9983]], requires_grad=True)
# 3000 7.5E-05 7.3E-05 1.3E-06 0.0E+00
# tensor([[ 0.0995],
#         [-0.9986]], requires_grad=True)
# 3500 7.5E-05 7.3E-05 1.4E-06 0.0E+00
# tensor([[ 0.0995],
#         [-0.9987]], requires_grad=True)
# 4000 7.5E-05 7.3E-05 1.4E-06 0.0E+00
# tensor([[ 0.0994],
#         [-0.9989]], requires_grad=True)
# 4500 7.5E-05 7.3E-05 1.4E-06 0.0E+00
# tensor([[ 0.0995],
#         [-0.9989]], requires_grad=True)
# 5000 7.4E-05 7.3E-05 1.4E-06 0.0E+00
# tensor([[ 0.0995],
#         [-0.9990]], requires_grad=True)
# 5500 7.4E-05 7.3E-05 1.4E-06 0.0E+00
# tensor([[ 0.0995],
#         [-0.9990]], requires_grad=True)
# 6000 7.6E-05 7.5E-05 1.5E-06 0.0E+00
# tensor([[ 0.0993],
#         [-0.9992]], requires_grad=True)
# 6500 8.0E-05 7.8E-05 1.8E-06 0.0E+00
# tensor([[ 0.0990],
#         [-0.9992]], requires_grad=True)
# 7000 7.5E-05 7.3E-05 1.5E-06 0.0E+00
# tensor([[ 0.0996],
#         [-0.9990]], requires_grad=True)
# 7500 7.6E-05 7.4E-05 1.6E-06 0.0E+00
# tensor([[ 0.0995],
#         [-0.9990]], requires_grad=True)
# 8000 7.7E-05 7.5E-05 1.6E-06 0.0E+00
# tensor([[ 0.0995],
#         [-0.9990]], requires_grad=True)
# 8500 7.4E-05 7.3E-05 1.5E-06 0.0E+00
# tensor([[ 0.0996],
#         [-0.9989]], requires_grad=True)
# 9000 7.5E-05 7.3E-05 1.6E-06 0.0E+00
# tensor([[ 0.0995],
#         [-0.9989]], requires_grad=True)
# 9500 7.5E-05 7.4E-05 1.6E-06 0.0E+00
# tensor([[ 0.0996],
#         [-0.9990]], requires_grad=True)
# 10000 7.4E-05 7.2E-05 1.6E-06 0.0E+00
# tensor([[ 0.0996],
#         [-0.9990]], requires_grad=True)
# 10500 7.4E-05 7.2E-05 1.6E-06 0.0E+00
# tensor([[ 0.0996],
#         [-0.9991]], requires_grad=True)
# 11000 7.4E-05 7.3E-05 1.6E-06 0.0E+00
# tensor([[ 0.0997],
#         [-0.9990]], requires_grad=True)
# 11500 7.4E-05 7.2E-05 1.6E-06 0.0E+00
# tensor([[ 0.0996],
#         [-0.9992]], requires_grad=True)
# 12000 7.4E-05 7.2E-05 1.6E-06 0.0E+00
# tensor([[ 0.0995],
#         [-0.9994]], requires_grad=True)
# 12500 7.4E-05 7.2E-05 1.6E-06 0.0E+00
# tensor([[ 0.0995],
#         [-0.9994]], requires_grad=True)
# 13000 7.4E-05 7.2E-05 1.6E-06 0.0E+00
# tensor([[ 0.0995],
#         [-0.9995]], requires_grad=True)
# 13500 7.4E-05 7.2E-05 1.6E-06 0.0E+00
# tensor([[ 0.0995],
#         [-0.9996]], requires_grad=True)
# 14000 7.7E-05 7.5E-05 1.8E-06 0.0E+00
# tensor([[ 0.0994],
#         [-0.9997]], requires_grad=True)
# 14500 7.4E-05 7.2E-05 1.6E-06 0.0E+00
# tensor([[ 0.0995],
#         [-0.9997]], requires_grad=True)
# 15000 7.5E-05 7.4E-05 1.8E-06 0.0E+00
# tensor([[ 0.0996],
#         [-0.9997]], requires_grad=True)
# 15500 7.4E-05 7.2E-05 1.7E-06 0.0E+00
# tensor([[ 0.0995],
#         [-0.9999]], requires_grad=True)
# 16000 7.5E-05 7.3E-05 1.7E-06 0.0E+00
# tensor([[ 0.0994],
#         [-1.0000]], requires_grad=True)
# 16500 8.6E-05 8.4E-05 1.9E-06 0.0E+00
# tensor([[ 0.0993],
#         [-1.0000]], requires_grad=True)
# 17000 7.4E-05 7.2E-05 1.7E-06 0.0E+00
# tensor([[ 0.0995],
#         [-0.9999]], requires_grad=True)
# 17500 7.4E-05 7.2E-05 1.7E-06 0.0E+00
# tensor([[ 0.0994],
#         [-1.0001]], requires_grad=True)
# 18000 7.4E-05 7.2E-05 1.7E-06 0.0E+00
# tensor([[ 0.0995],
#         [-1.0000]], requires_grad=True)
# 18500 7.3E-05 7.2E-05 1.7E-06 0.0E+00
# tensor([[ 0.0995],
#         [-1.0000]], requires_grad=True)
# 19000 7.4E-05 7.2E-05 1.8E-06 0.0E+00
# tensor([[ 0.0995],
#         [-1.0000]], requires_grad=True)
# 19500 7.4E-05 7.2E-05 1.8E-06 0.0E+00
# tensor([[ 0.0995],
#         [-0.9999]], requires_grad=True)

# %% [markdown]
# Now that DeepMoD has converged, it has found the following equation:

# %%
print('Final result:')
print(sparse_coeff_vector, sparsity_mask)
# Out:
# Final result:
# (tensor([[ 0.0994],
#         [-1.0001]], requires_grad=True),) (tensor([2, 5]),)
